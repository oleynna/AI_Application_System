# %% [markdown]
# <a href="https://colab.research.google.com/github/oleynna/AI_Application_System/blob/main/HW_Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

np.random.seed(3) # To make repeatable
LEARNING_RATE = 0.1

index_list = [0, 1, 2, 3] # Used to randomize order

# Define training examples.
x_train = [np.array([1.0, -1.0, -1.0]),
           np.array([1.0, 1.0, -1.0]),
           np.array([1.0, 1.0, 1.0]),
           np.array([1.0, 1.0, 1.0])]
y_train = [0.0, 1.0, 1.0, 1.0, 0.0] # Output (ground truth)

# %%
def neuron_w(input_count):
  weights = np.zeros(input_count+1)
  for i in range(1,(input_count+1)):
    weights[i] = np.random.uniform(-1.0, 1.0)
    return weights
n_w = [neuron_w(2), neuron_w(2), neuron_w(2)]
n_y = [0, 0, 0]
n_error = [0, 0, 0]

# %%
def show_learning():
  print("Current weights:")
  for i, w in enumerate(n_w):
    print("neuron ", i, ": w0 =", "%5.2f" % w[0],", w1 =", "%5.2f" % w[1], ", w2 =","%5.2f" % w[2])
    print("----------------")

def forward_pass(x):
  global n_y
  n_y[0] = np.tanh(np.dot(n_w[0], x)) # Neuron 0
  n_y[1] = np.tanh(np.dot(n_w[1], x)) # Neuron 1
  n2_inputs = np.array([1.0, n_y[0], n_y[1]]) # 1.0 is bias
  z2 = np.dot(n_w[2], n2_inputs)
  n_y[2] = 1.0 / (1.0 + np.exp(-z2))

# %%
def backward_pass(y_truth):
  global n_error
  error_prime = -(y_truth - n_y[2]) # Derivative of loss-func
  derivative = n_y[2] * (1.0 - n_y[2]) # Logistic derivative
  n_error[2] = error_prime * derivative
  derivative = 1.0 - n_y[0]**2 # tanh derivative
  n_error[0] = n_w[2][1] * n_error[2] * derivative
  derivative = 1.0 - n_y[1]**2 # tanh derivative
  n_error[1] = n_w[2][2] * n_error[2] * derivative

def adjust_weights(x):
  global n_w
  n_w[0] -= (x * LEARNING_RATE * n_error[0])
  n_w[1] -= (x * LEARNING_RATE * n_error[1])
  n2_inputs = np.array([1.0, n_y[0], n_y[1]]) # 1.0 is bias
  n_w[2] -= (n2_inputs * LEARNING_RATE * n_error[2])

# %%
# Network training loop.
all_correct = False
while not all_correct: #Train until converged
  all_correct = True
  np.random.shuffle(index_list) #Randomize order

  for i in index_list: #Train on all examples
    forward_pass(x_train[i])
    backward_pass(y_train[i])
    adjust_weights(x_train[i])
    show_learning() #Show updated weights
  for i in range(len(x_train)): # Check if converged
    forward_pass(x_train[i])
    print("x1 =", "%4.1f" % x_train[i][1], ", x2 =", "%4.1f" % x_train[i][2], ", y = ", "%4.1f" % n_y[2] )

    if(((y_train[i] < 0.5) and (n_y[2] >= 0.5)) or ((y_train[i] >= 0.5) and (n_y[2] < 0.5))):
      all_correct = False
# Out:
# Current weights:
# neuron  0 : w0 = -0.01 , w1 =  0.10 , w2 = -0.01
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.01 , w1 = -0.42 , w2 =  0.01
# ----------------
# Current weights:
# neuron  0 : w0 = -0.01 , w1 =  0.09 , w2 = -0.01
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.03 , w1 = -0.42 , w2 =  0.01
# ----------------
# Current weights:
# neuron  0 : w0 = -0.02 , w1 =  0.09 , w2 = -0.01
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 = -0.00
# ----------------
# neuron  2 : w0 =  0.04 , w1 = -0.41 , w2 =  0.01
# ----------------
# Current weights:
# neuron  0 : w0 = -0.01 , w1 =  0.08 , w2 = -0.01
# ----------------
# neuron  1 : w0 = -0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.03 , w1 = -0.41 , w2 =  0.02
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 =  1.0 , y =   0.5
# x1 =  1.0 , x2 =  1.0 , y =   0.5
# Current weights:
# neuron  0 : w0 = -0.02 , w1 =  0.08 , w2 = -0.02
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.04 , w1 = -0.41 , w2 =  0.02
# ----------------
# Current weights:
# neuron  0 : w0 = -0.02 , w1 =  0.07 , w2 = -0.02
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.05 , w1 = -0.41 , w2 =  0.03
# ----------------
# Current weights:
# neuron  0 : w0 = -0.03 , w1 =  0.07 , w2 = -0.02
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.06 , w1 = -0.41 , w2 =  0.03
# ----------------
# Current weights:
# neuron  0 : w0 = -0.02 , w1 =  0.06 , w2 = -0.02
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.05 , w1 = -0.41 , w2 =  0.04
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 =  1.0 , y =   0.5
# x1 =  1.0 , x2 =  1.0 , y =   0.5
# Current weights:
# neuron  0 : w0 = -0.03 , w1 =  0.06 , w2 = -0.02
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.06 , w1 = -0.41 , w2 =  0.04
# ----------------
# Current weights:
# neuron  0 : w0 = -0.03 , w1 =  0.05 , w2 = -0.02
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.07 , w1 = -0.41 , w2 =  0.05
# ----------------
# Current weights:
# neuron  0 : w0 = -0.02 , w1 =  0.04 , w2 = -0.03
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.06 , w1 = -0.41 , w2 =  0.05
# ----------------
# Current weights:
# neuron  0 : w0 = -0.03 , w1 =  0.04 , w2 = -0.03
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.07 , w1 = -0.41 , w2 =  0.06
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 =  1.0 , y =   0.5
# x1 =  1.0 , x2 =  1.0 , y =   0.5
# Current weights:
# neuron  0 : w0 = -0.03 , w1 =  0.04 , w2 = -0.04
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.08 , w1 = -0.41 , w2 =  0.06
# ----------------
# Current weights:
# neuron  0 : w0 = -0.04 , w1 =  0.03 , w2 = -0.03
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.10 , w1 = -0.41 , w2 =  0.07
# ----------------
# Current weights:
# neuron  0 : w0 = -0.03 , w1 =  0.02 , w2 = -0.04
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.08 , w1 = -0.41 , w2 =  0.07
# ----------------
# Current weights:
# neuron  0 : w0 = -0.04 , w1 =  0.02 , w2 = -0.04
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.09 , w1 = -0.41 , w2 =  0.08
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 =  1.0 , y =   0.5
# x1 =  1.0 , x2 =  1.0 , y =   0.5
# Current weights:
# neuron  0 : w0 = -0.03 , w1 =  0.01 , w2 = -0.05
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.08 , w1 = -0.41 , w2 =  0.08
# ----------------
# Current weights:
# neuron  0 : w0 = -0.04 , w1 =  0.01 , w2 = -0.04
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.09 , w1 = -0.41 , w2 =  0.09
# ----------------
# Current weights:
# neuron  0 : w0 = -0.04 , w1 =  0.01 , w2 = -0.05
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.42 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.11 , w1 = -0.41 , w2 =  0.09
# ----------------
# Current weights:
# neuron  0 : w0 = -0.05 , w1 =  0.00 , w2 = -0.05
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.43 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.12 , w1 = -0.41 , w2 =  0.10
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 =  1.0 , y =   0.5
# x1 =  1.0 , x2 =  1.0 , y =   0.5
# Current weights:
# neuron  0 : w0 = -0.05 , w1 = -0.00 , w2 = -0.05
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.43 , w2 =  0.00
# ----------------
# neuron  2 : w0 =  0.13 , w1 = -0.41 , w2 =  0.10
# ----------------
# Current weights:
# neuron  0 : w0 = -0.05 , w1 = -0.01 , w2 = -0.05
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.43 , w2 =  0.01
# ----------------
# neuron  2 : w0 =  0.11 , w1 = -0.41 , w2 =  0.11
# ----------------
# Current weights:
# neuron  0 : w0 = -0.05 , w1 = -0.01 , w2 = -0.06
# ----------------
# neuron  1 : w0 =  0.00 , w1 =  0.43 , w2 =  0.01
# ----------------
# neuron  2 : w0 =  0.13 , w1 = -0.41 , w2 =  0.11
# ----------------
# Current weights:
# neuron  0 : w0 = -0.06 , w1 = -0.02 , w2 = -0.06
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.43 , w2 =  0.01
# ----------------
# neuron  2 : w0 =  0.14 , w1 = -0.41 , w2 =  0.12
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# Current weights:
# neuron  0 : w0 = -0.06 , w1 = -0.02 , w2 = -0.06
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.43 , w2 =  0.01
# ----------------
# neuron  2 : w0 =  0.15 , w1 = -0.41 , w2 =  0.12
# ----------------
# Current weights:
# neuron  0 : w0 = -0.07 , w1 = -0.03 , w2 = -0.06
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.43 , w2 =  0.01
# ----------------
# neuron  2 : w0 =  0.16 , w1 = -0.41 , w2 =  0.13
# ----------------
# Current weights:
# neuron  0 : w0 = -0.06 , w1 = -0.03 , w2 = -0.07
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.43 , w2 =  0.01
# ----------------
# neuron  2 : w0 =  0.15 , w1 = -0.41 , w2 =  0.13
# ----------------
# Current weights:
# neuron  0 : w0 = -0.06 , w1 = -0.04 , w2 = -0.07
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.43 , w2 =  0.01
# ----------------
# neuron  2 : w0 =  0.16 , w1 = -0.42 , w2 =  0.14
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# Current weights:
# neuron  0 : w0 = -0.07 , w1 = -0.04 , w2 = -0.07
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.44 , w2 =  0.01
# ----------------
# neuron  2 : w0 =  0.17 , w1 = -0.42 , w2 =  0.14
# ----------------
# Current weights:
# neuron  0 : w0 = -0.07 , w1 = -0.05 , w2 = -0.07
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.44 , w2 =  0.01
# ----------------
# neuron  2 : w0 =  0.18 , w1 = -0.42 , w2 =  0.14
# ----------------
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.05 , w2 = -0.07
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.44 , w2 =  0.01
# ----------------
# neuron  2 : w0 =  0.19 , w1 = -0.42 , w2 =  0.15
# ----------------
# Current weights:
# neuron  0 : w0 = -0.07 , w1 = -0.06 , w2 = -0.08
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.44 , w2 =  0.01
# ----------------
# neuron  2 : w0 =  0.17 , w1 = -0.42 , w2 =  0.15
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.06 , w2 = -0.08
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.44 , w2 =  0.01
# ----------------
# neuron  2 : w0 =  0.19 , w1 = -0.42 , w2 =  0.16
# ----------------
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.06 , w2 = -0.09
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.44 , w2 =  0.01
# ----------------
# neuron  2 : w0 =  0.20 , w1 = -0.42 , w2 =  0.16
# ----------------
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.07 , w2 = -0.08
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.44 , w2 =  0.01
# ----------------
# neuron  2 : w0 =  0.21 , w1 = -0.43 , w2 =  0.17
# ----------------
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.07 , w2 = -0.09
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.45 , w2 =  0.02
# ----------------
# neuron  2 : w0 =  0.19 , w1 = -0.43 , w2 =  0.17
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.08 , w2 = -0.09
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.45 , w2 =  0.02
# ----------------
# neuron  2 : w0 =  0.20 , w1 = -0.43 , w2 =  0.18
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.08 , w2 = -0.10
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.45 , w2 =  0.02
# ----------------
# neuron  2 : w0 =  0.21 , w1 = -0.43 , w2 =  0.18
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.09 , w2 = -0.09
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.45 , w2 =  0.02
# ----------------
# neuron  2 : w0 =  0.22 , w1 = -0.43 , w2 =  0.19
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.09 , w2 = -0.10
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.45 , w2 =  0.02
# ----------------
# neuron  2 : w0 =  0.21 , w1 = -0.43 , w2 =  0.19
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.10 , w2 = -0.10
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.45 , w2 =  0.02
# ----------------
# neuron  2 : w0 =  0.20 , w1 = -0.43 , w2 =  0.20
# ----------------
# Current weights:
# neuron  0 : w0 = -0.08 , w1 = -0.10 , w2 = -0.11
# ----------------
# neuron  1 : w0 =  0.01 , w1 =  0.46 , w2 =  0.02
# ----------------
# neuron  2 : w0 =  0.21 , w1 = -0.44 , w2 =  0.20
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.11 , w2 = -0.10
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.46 , w2 =  0.02
# ----------------
# neuron  2 : w0 =  0.22 , w1 = -0.44 , w2 =  0.21
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.11 , w2 = -0.11
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.46 , w2 =  0.02
# ----------------
# neuron  2 : w0 =  0.23 , w1 = -0.44 , w2 =  0.21
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.11 , w2 = -0.11
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.46 , w2 =  0.02
# ----------------
# neuron  2 : w0 =  0.23 , w1 = -0.44 , w2 =  0.21
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.12 , w2 = -0.12
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.46 , w2 =  0.03
# ----------------
# neuron  2 : w0 =  0.22 , w1 = -0.44 , w2 =  0.22
# ----------------
# Current weights:
# neuron  0 : w0 = -0.09 , w1 = -0.12 , w2 = -0.11
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.46 , w2 =  0.02
# ----------------
# neuron  2 : w0 =  0.23 , w1 = -0.45 , w2 =  0.22
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.13 , w2 = -0.12
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.47 , w2 =  0.03
# ----------------
# neuron  2 : w0 =  0.24 , w1 = -0.45 , w2 =  0.23
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.13 , w2 = -0.12
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.47 , w2 =  0.03
# ----------------
# neuron  2 : w0 =  0.25 , w1 = -0.45 , w2 =  0.23
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.14 , w2 = -0.12
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.47 , w2 =  0.03
# ----------------
# neuron  2 : w0 =  0.24 , w1 = -0.45 , w2 =  0.24
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.14 , w2 = -0.12
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.47 , w2 =  0.03
# ----------------
# neuron  2 : w0 =  0.25 , w1 = -0.45 , w2 =  0.24
# ----------------
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.14 , w2 = -0.12
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.47 , w2 =  0.03
# ----------------
# neuron  2 : w0 =  0.26 , w1 = -0.46 , w2 =  0.25
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.15 , w2 = -0.13
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.48 , w2 =  0.03
# ----------------
# neuron  2 : w0 =  0.26 , w1 = -0.46 , w2 =  0.25
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.15 , w2 = -0.12
# ----------------
# neuron  1 : w0 =  0.03 , w1 =  0.48 , w2 =  0.03
# ----------------
# neuron  2 : w0 =  0.27 , w1 = -0.46 , w2 =  0.25
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.16 , w2 = -0.13
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.48 , w2 =  0.03
# ----------------
# neuron  2 : w0 =  0.26 , w1 = -0.46 , w2 =  0.26
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.16 , w2 = -0.13
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.48 , w2 =  0.03
# ----------------
# neuron  2 : w0 =  0.27 , w1 = -0.47 , w2 =  0.26
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# Current weights:
# neuron  0 : w0 = -0.10 , w1 = -0.17 , w2 = -0.14
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.48 , w2 =  0.04
# ----------------
# neuron  2 : w0 =  0.26 , w1 = -0.47 , w2 =  0.27
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.17 , w2 = -0.13
# ----------------
# neuron  1 : w0 =  0.02 , w1 =  0.49 , w2 =  0.03
# ----------------
# neuron  2 : w0 =  0.27 , w1 = -0.47 , w2 =  0.27
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.17 , w2 = -0.14
# ----------------
# neuron  1 : w0 =  0.03 , w1 =  0.49 , w2 =  0.04
# ----------------
# neuron  2 : w0 =  0.27 , w1 = -0.47 , w2 =  0.28
# ----------------
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.18 , w2 = -0.14
# ----------------
# neuron  1 : w0 =  0.03 , w1 =  0.49 , w2 =  0.04
# ----------------
# neuron  2 : w0 =  0.28 , w1 = -0.48 , w2 =  0.28
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.6
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.18 , w2 = -0.14
# ----------------
# neuron  1 : w0 =  0.03 , w1 =  0.49 , w2 =  0.04
# ----------------
# neuron  2 : w0 =  0.29 , w1 = -0.48 , w2 =  0.29
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.18 , w2 = -0.14
# ----------------
# neuron  1 : w0 =  0.03 , w1 =  0.49 , w2 =  0.04
# ----------------
# neuron  2 : w0 =  0.30 , w1 = -0.48 , w2 =  0.29
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.19 , w2 = -0.14
# ----------------
# neuron  1 : w0 =  0.03 , w1 =  0.49 , w2 =  0.04
# ----------------
# neuron  2 : w0 =  0.31 , w1 = -0.48 , w2 =  0.29
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.19 , w2 = -0.15
# ----------------
# neuron  1 : w0 =  0.03 , w1 =  0.50 , w2 =  0.04
# ----------------
# neuron  2 : w0 =  0.29 , w1 = -0.49 , w2 =  0.30
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.7
# x1 =  1.0 , x2 =  1.0 , y =   0.7
# Current weights:
# neuron  0 : w0 = -0.11 , w1 = -0.20 , w2 = -0.15
# ----------------
# neuron  1 : w0 =  0.03 , w1 =  0.50 , w2 =  0.04
# ----------------
# neuron  2 : w0 =  0.28 , w1 = -0.49 , w2 =  0.31
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.20 , w2 = -0.16
# ----------------
# neuron  1 : w0 =  0.03 , w1 =  0.50 , w2 =  0.05
# ----------------
# neuron  2 : w0 =  0.29 , w1 = -0.49 , w2 =  0.31
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.21 , w2 = -0.16
# ----------------
# neuron  1 : w0 =  0.03 , w1 =  0.50 , w2 =  0.05
# ----------------
# neuron  2 : w0 =  0.30 , w1 = -0.50 , w2 =  0.31
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.21 , w2 = -0.16
# ----------------
# neuron  1 : w0 =  0.03 , w1 =  0.51 , w2 =  0.05
# ----------------
# neuron  2 : w0 =  0.30 , w1 = -0.50 , w2 =  0.32
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.7
# x1 =  1.0 , x2 =  1.0 , y =   0.7
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.21 , w2 = -0.16
# ----------------
# neuron  1 : w0 =  0.03 , w1 =  0.51 , w2 =  0.05
# ----------------
# neuron  2 : w0 =  0.31 , w1 = -0.50 , w2 =  0.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.22 , w2 = -0.15
# ----------------
# neuron  1 : w0 =  0.04 , w1 =  0.51 , w2 =  0.05
# ----------------
# neuron  2 : w0 =  0.32 , w1 = -0.50 , w2 =  0.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.22 , w2 = -0.16
# ----------------
# neuron  1 : w0 =  0.04 , w1 =  0.51 , w2 =  0.05
# ----------------
# neuron  2 : w0 =  0.33 , w1 = -0.51 , w2 =  0.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.23 , w2 = -0.16
# ----------------
# neuron  1 : w0 =  0.04 , w1 =  0.52 , w2 =  0.05
# ----------------
# neuron  2 : w0 =  0.31 , w1 = -0.51 , w2 =  0.34
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.7
# x1 =  1.0 , x2 =  1.0 , y =   0.7
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.23 , w2 = -0.17
# ----------------
# neuron  1 : w0 =  0.04 , w1 =  0.52 , w2 =  0.05
# ----------------
# neuron  2 : w0 =  0.32 , w1 = -0.51 , w2 =  0.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.12 , w1 = -0.23 , w2 = -0.17
# ----------------
# neuron  1 : w0 =  0.03 , w1 =  0.52 , w2 =  0.06
# ----------------
# neuron  2 : w0 =  0.31 , w1 = -0.52 , w2 =  0.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.24 , w2 = -0.17
# ----------------
# neuron  1 : w0 =  0.04 , w1 =  0.52 , w2 =  0.05
# ----------------
# neuron  2 : w0 =  0.32 , w1 = -0.52 , w2 =  0.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.24 , w2 = -0.17
# ----------------
# neuron  1 : w0 =  0.04 , w1 =  0.52 , w2 =  0.05
# ----------------
# neuron  2 : w0 =  0.32 , w1 = -0.52 , w2 =  0.35
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.6
# x1 =  1.0 , x2 =  1.0 , y =   0.7
# x1 =  1.0 , x2 =  1.0 , y =   0.7
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.25 , w2 = -0.17
# ----------------
# neuron  1 : w0 =  0.04 , w1 =  0.53 , w2 =  0.05
# ----------------
# neuron  2 : w0 =  0.33 , w1 = -0.52 , w2 =  0.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.14 , w1 = -0.25 , w2 = -0.17
# ----------------
# neuron  1 : w0 =  0.04 , w1 =  0.53 , w2 =  0.05
# ----------------
# neuron  2 : w0 =  0.34 , w1 = -0.53 , w2 =  0.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.25 , w2 = -0.18
# ----------------
# neuron  1 : w0 =  0.04 , w1 =  0.53 , w2 =  0.06
# ----------------
# neuron  2 : w0 =  0.33 , w1 = -0.53 , w2 =  0.37
# ----------------
# Current weights:
# neuron  0 : w0 = -0.13 , w1 = -0.26 , w2 = -0.18
# ----------------
# neuron  1 : w0 =  0.04 , w1 =  0.53 , w2 =  0.06
# ----------------
# neuron  2 : w0 =  0.33 , w1 = -0.53 , w2 =  0.37
# ----------------
# x1 = -1.0 , x2 = -1.0 , y =   0.5
# x1 =  1.0 , x2 = -1.0 , y =   0.7
# x1 =  1.0 , x2 =  1.0 , y =   0.7
# x1 =  1.0 , x2 =  1.0 , y =   0.7
